# %%
import os
from PIL import Image
from PIL import ImageFilter
import numpy as np
import keras
import pandas as pd
from keras.layers import Dense, Dropout, Activation, Flatten,BatchNormalization
from keras.layers import Conv2D, MaxPool2D, AveragePooling2D
from keras.models import Sequential
# Out:
# /anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from keras.layers import GlobalAveragePooling2D

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = ''
num_classes = 10
epochs = 200
batch_size = 4

# %%
opt = keras.optimizers.rmsprop(lr=0.01, decay=1e-6)

# %%
img_rows, img_cols = 32, 32

# %%
os.chdir("/Users/sandeshbhaiswar/Downloads/flower_images")

# %%
df = pd.read_csv('/Users/sandeshbhaiswar/Downloads/flower_images/flower_labels.csv')#load images' names and labels
names = df['file'].values
labels = df['label'].values.reshape(-1,1)

# %%
data = []

# %%
for name in names:
    img = Image.open(name)#shape is 128x128x4
    img = img.resize((img_rows, img_cols))#resize image into fixed size 32x32x4
    img = np.array(img)[np.newaxis, :, :, :3]#add new axis and new size is 1x32x32x3
    data.append(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-2c6a282670af> in <module>()
#       1 for name in names:
# ----> 2     img = Image.open(name)#shape is 128x128x4
#       3     img = img.resize((img_rows, img_cols))#resize image into fixed size 32x32x4
#       4     img = np.array(img)[np.newaxis, :, :, :3]#add new axis and new size is 1x32x32x3
#       5     data.append(img)
#
# /anaconda3/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2541
#    2542     if filename:
# -> 2543         fp = builtins.open(filename, "rb")
#    2544         exclusive_fp = True
#    2545
#
# FileNotFoundError: [Errno 2] No such file or directory: '0001.png'

# %%
data = np.concatenate(data)#concatenate images, shape is 209x128x128x3

# %%
x_train = data[:177].astype(np.float32)
y_train = labels[:177]
x_test = data[177:].astype(np.float32)# set the last 32 images as test dataset
y_test = labels[177:]
x_train /= 255
x_test /= 255

# %%
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)#convert label into one-hot vector

# %%
model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='valid', input_shape=[32,32,3]))#Convolution
model.add(Activation('relu'))#Activation function
model.add(AveragePooling2D(pool_size=(30, 30)))#30x30 average pooling
model.add(Flatten())# shape equals to [batch_size, 32] 32 is the number of filters
model.add(Dense(10))#Fully connected layer
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
def train():
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)

# %%
train()
# Out:
# Train on 177 samples, validate on 32 samples
# Epoch 1/50
# 177/177 [==============================] - 0s 2ms/step - loss: 2.3220 - acc: 0.1073 - val_loss: 2.2671 - val_acc: 0.0625
# Epoch 2/50
# 177/177 [==============================] - 0s 1ms/step - loss: 2.2720 - acc: 0.1638 - val_loss: 2.2757 - val_acc: 0.0938
# Epoch 3/50
# 177/177 [==============================] - 0s 2ms/step - loss: 2.1311 - acc: 0.2373 - val_loss: 2.2581 - val_acc: 0.0625
# Epoch 4/50
# 177/177 [==============================] - 0s 2ms/step - loss: 2.0303 - acc: 0.2034 - val_loss: 2.0853 - val_acc: 0.0938
# Epoch 5/50
# 177/177 [==============================] - 0s 1ms/step - loss: 1.9428 - acc: 0.2599 - val_loss: 2.2102 - val_acc: 0.1250
# Epoch 6/50
# 177/177 [==============================] - 0s 2ms/step - loss: 1.8712 - acc: 0.2599 - val_loss: 2.2626 - val_acc: 0.1250
# Epoch 7/50
# 177/177 [==============================] - 0s 1ms/step - loss: 1.8015 - acc: 0.3559 - val_loss: 2.1782 - val_acc: 0.2188
# ...

# %%
model2 = Sequential()
model2.add(Conv2D(filters=32, kernel_size=(3,3), padding='valid', input_shape=[32,32,3]))#Convolution
#model2.add(BatchNormalization())
model2.add(Activation('relu'))#Activation function
model2.add(AveragePooling2D(pool_size=(2, 2)))#2x2 average pooling
model2.add(Conv2D(filters=32, kernel_size=(3,3), padding='valid'))#Convolution
model2.add(Activation('relu'))#Activation function
model2.add(GlobalAveragePooling2D())#Global pooling
#model2.add(Flatten())# shape equals to [batch_size, 32] 32 is the number of filters
model2.add(Dense(10))#Fully connected layer
model2.add(Activation('softmax'))

# %%
model2.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
def train2():
    model2.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)

# %%
train2()
# Out:
# Train on 177 samples, validate on 32 samples
# Epoch 1/200
# 177/177 [==============================] - 1s 3ms/step - loss: 2.3143 - acc: 0.1751 - val_loss: 2.5270 - val_acc: 0.1562
# Epoch 2/200
# 177/177 [==============================] - 0s 2ms/step - loss: 2.0971 - acc: 0.1921 - val_loss: 2.1146 - val_acc: 0.1562
# Epoch 3/200
# 177/177 [==============================] - 0s 3ms/step - loss: 1.9643 - acc: 0.2712 - val_loss: 1.9940 - val_acc: 0.2500
# Epoch 4/200
# 177/177 [==============================] - 0s 3ms/step - loss: 1.7091 - acc: 0.3559 - val_loss: 1.7734 - val_acc: 0.2812
# Epoch 5/200
# 177/177 [==============================] - 0s 3ms/step - loss: 1.4944 - acc: 0.4011 - val_loss: 1.9256 - val_acc: 0.2812
# Epoch 6/200
# 177/177 [==============================] - 0s 3ms/step - loss: 1.4799 - acc: 0.4633 - val_loss: 1.4620 - val_acc: 0.5000
# Epoch 7/200
# ...

# %%
model3 = Sequential()
model3.add(Conv2D(filters = 32, kernel_size = (3,3), padding = 'valid', input_shape = [32,32,3]))
model3.add(Activation('relu'))
model3.add(AveragePooling2D(pool_size = (2,2)))
model3.add(Conv2D(filters = 32, kernel_size = (3,3), padding = 'valid'))
model3.add(Activation('relu'))
model3.add(AveragePooling2D(pool_size = (2,2)))
model3.add(Conv2D(filters = 32, kernel_size = (3,3), padding = 'valid'))
model3.add(Activation('relu'))
model3.add(GlobalAveragePooling2D())
model3.add(Dense(10))
model3.add(Activation('softmax'))

# %%
model3.compile(loss = 'categorical_crossentropy', optimizer = opt, metrics = ['accuracy'])

# %%
def train3():
    model3.fit(x_train, y_train, 
               batch_size = batch_size, 
               epochs = epochs, 
               validation_data = (x_test, y_test), 
               shuffle = True)

# %%
train3()
# Out:
# Train on 177 samples, validate on 32 samples
# Epoch 1/50
# 177/177 [==============================] - 1s 4ms/step - loss: 2.3636 - acc: 0.0734 - val_loss: 2.3076 - val_acc: 0.0938
# Epoch 2/50
# 177/177 [==============================] - 1s 3ms/step - loss: 2.2631 - acc: 0.1864 - val_loss: 2.2367 - val_acc: 0.0938
# Epoch 3/50
# 177/177 [==============================] - 0s 3ms/step - loss: 2.0211 - acc: 0.2994 - val_loss: 2.3102 - val_acc: 0.2188
# Epoch 4/50
# 177/177 [==============================] - 1s 3ms/step - loss: 1.8614 - acc: 0.3107 - val_loss: 6.6103 - val_acc: 0.1250
# Epoch 5/50
# 177/177 [==============================] - 1s 3ms/step - loss: 1.9937 - acc: 0.3164 - val_loss: 2.0745 - val_acc: 0.1875
# Epoch 6/50
# 177/177 [==============================] - 1s 3ms/step - loss: 1.8845 - acc: 0.3729 - val_loss: 1.8359 - val_acc: 0.2188
# Epoch 7/50
# 177/177 [==============================] - 0s 3ms/step - loss: 1.5948 - acc: 0.3785 - val_loss: 1.9501 - val_acc: 0.4062
# ...

# %%
model4 = Sequential()
model4.add(Conv2D(filters=32, kernel_size=(5,5), padding='valid', input_shape=[32,32,3]))#Convolution
model4.add(Activation('relu'))#Activation function
model4.add(AveragePooling2D(pool_size=(2, 2)))#2x2 average pooling
model4.add(Conv2D(filters=32, kernel_size=(3,3), padding='valid'))#Convolution
model4.add(Activation('relu'))#Activation function
model4.add(GlobalAveragePooling2D())#Global pooling
model4.add(Dense(10))#Fully connected layer
model4.add(Activation('softmax'))

# %%
model4.compile(loss = 'categorical_crossentropy', optimizer = opt, metrics = ['accuracy'])

# %%
def train4():
    model4.fit(x_train, y_train, 
               batch_size = batch_size, 
               epochs = epochs, 
               validation_data = (x_test, y_test), 
               shuffle = True)

# %%
train4()
# Out:
# Train on 177 samples, validate on 32 samples
# Epoch 1/50
# 177/177 [==============================] - 1s 4ms/step - loss: 2.5468 - acc: 0.1469 - val_loss: 2.2650 - val_acc: 0.0625
# Epoch 2/50
# 177/177 [==============================] - 0s 3ms/step - loss: 2.1628 - acc: 0.1864 - val_loss: 2.1632 - val_acc: 0.1875
# Epoch 3/50
# 177/177 [==============================] - 1s 3ms/step - loss: 1.9790 - acc: 0.2655 - val_loss: 2.4031 - val_acc: 0.1875
# Epoch 4/50
# 177/177 [==============================] - 1s 3ms/step - loss: 1.8763 - acc: 0.2938 - val_loss: 2.0793 - val_acc: 0.2188
# Epoch 5/50
# 177/177 [==============================] - 1s 3ms/step - loss: 1.7847 - acc: 0.3333 - val_loss: 1.8626 - val_acc: 0.2812
# Epoch 6/50
# 177/177 [==============================] - 1s 3ms/step - loss: 1.5458 - acc: 0.3446 - val_loss: 2.1300 - val_acc: 0.3438
# Epoch 7/50
# 177/177 [==============================] - 1s 3ms/step - loss: 1.6607 - acc: 0.4011 - val_loss: 2.0503 - val_acc: 0.1875
# ...

# %%
model5 = Sequential()
model5.add(Conv2D(filters=32, kernel_size=(5,5), padding='valid', input_shape=[32,32,3]))#Convolution
model5.add(Activation('relu'))#Activation function
model5.add(AveragePooling2D(pool_size=(2, 2)))#2x2 average pooling
model5.add(Conv2D(filters=32, kernel_size=(5,5), padding='valid'))#Convolution
model5.add(Activation('relu'))#Activation function
model5.add(GlobalAveragePooling2D())#Global pooling
model5.add(Dense(10))#Fully connected layer
model5.add(Activation('softmax'))

# %%
model5.compile(loss = 'categorical_crossentropy', optimizer = opt, metrics = ['accuracy'])

# %%
def train5():
    model5.fit(x_train, y_train, 
               batch_size = batch_size, 
               epochs = epochs, 
               validation_data = (x_test, y_test), 
               shuffle = True)

# %%
train5()
# Out:
# Train on 177 samples, validate on 32 samples
# Epoch 1/50
# 177/177 [==============================] - 1s 5ms/step - loss: 2.6646 - acc: 0.0904 - val_loss: 2.3122 - val_acc: 0.0938
# Epoch 2/50
# 177/177 [==============================] - 1s 3ms/step - loss: 2.3165 - acc: 0.1921 - val_loss: 3.7043 - val_acc: 0.0312
# Epoch 3/50
# 177/177 [==============================] - 1s 3ms/step - loss: 2.2031 - acc: 0.2147 - val_loss: 2.0396 - val_acc: 0.1875
# Epoch 4/50
# 177/177 [==============================] - 1s 3ms/step - loss: 2.0233 - acc: 0.2429 - val_loss: 2.1941 - val_acc: 0.1250
# Epoch 5/50
# 177/177 [==============================] - 1s 3ms/step - loss: 1.9736 - acc: 0.2825 - val_loss: 3.9236 - val_acc: 0.1250
# Epoch 6/50
# 177/177 [==============================] - 1s 3ms/step - loss: 1.9356 - acc: 0.2825 - val_loss: 2.0119 - val_acc: 0.1250
# Epoch 7/50
# 177/177 [==============================] - 1s 3ms/step - loss: 2.0111 - acc: 0.2938 - val_loss: 2.2466 - val_acc: 0.2812
# ...

# %%
model6 = Sequential()
model6.add(Conv2D(filters = 32, kernel_size = (5,5), padding = 'valid', input_shape = [32,32,3]))
model6.add(Activation('relu'))
model6.add(AveragePooling2D(pool_size = (2,2)))
model6.add(Conv2D(filters = 32, kernel_size = (3,3), padding = 'valid'))
model6.add(Activation('relu'))
model6.add(AveragePooling2D(pool_size = (2,2)))
model6.add(Conv2D(filters = 32, kernel_size = (3,3), padding = 'valid'))
model6.add(Activation('relu'))
model6.add(GlobalAveragePooling2D())
model6.add(Dense(10))
model6.add(Activation('softmax'))

# %%
model6.compile(loss = 'categorical_crossentropy', optimizer = opt, metrics = ['accuracy'])

# %%
def train6():
    model6.fit(x_train, y_train, 
               batch_size = batch_size, 
               epochs = epochs, 
               validation_data = (x_test, y_test), 
               shuffle = True)

# %%
train6()
# Out:
# Train on 177 samples, validate on 32 samples
# Epoch 1/50
# 177/177 [==============================] - 1s 5ms/step - loss: 13.8945 - acc: 0.1186 - val_loss: 14.6070 - val_acc: 0.0938
# Epoch 2/50
# 177/177 [==============================] - 1s 3ms/step - loss: 14.0237 - acc: 0.1299 - val_loss: 14.6070 - val_acc: 0.0938
# Epoch 3/50
# 177/177 [==============================] - 1s 3ms/step - loss: 14.0237 - acc: 0.1299 - val_loss: 14.6070 - val_acc: 0.0938
# Epoch 4/50
# 177/177 [==============================] - 1s 3ms/step - loss: 14.0237 - acc: 0.1299 - val_loss: 14.6070 - val_acc: 0.0938
# Epoch 5/50
# 177/177 [==============================] - 1s 3ms/step - loss: 14.0237 - acc: 0.1299 - val_loss: 14.6070 - val_acc: 0.0938
# Epoch 6/50
# 177/177 [==============================] - 1s 3ms/step - loss: 14.0237 - acc: 0.1299 - val_loss: 14.6070 - val_acc: 0.0938
# Epoch 7/50
# ...

# %%
model7 = Sequential()
model7.add(Conv2D(filters = 32, kernel_size = (5,5), padding = 'valid', input_shape = [32,32,3]))
model7.add(Activation('relu'))
model7.add(AveragePooling2D(pool_size = (2,2)))
model7.add(Conv2D(filters = 32, kernel_size = (5,5), padding = 'valid'))
model7.add(Activation('relu'))
model7.add(AveragePooling2D(pool_size = (2,2)))
model7.add(Conv2D(filters = 32, kernel_size = (5,5), padding = 'valid'))
model7.add(Activation('relu'))
model7.add(GlobalAveragePooling2D())
model7.add(Dense(10))
model7.add(Activation('softmax'))

# %%
model7.compile(loss = 'categorical_crossentropy', optimizer = opt, metrics = ['accuracy'])

# %%
def train7():
    model7.fit(x_train, y_train, 
               batch_size = batch_size, 
               epochs = epochs, 
               validation_data = (x_test, y_test), 
               shuffle = True)

# %%
train7()
# Out:
# Train on 177 samples, validate on 32 samples
# Epoch 1/50
# 177/177 [==============================] - 1s 5ms/step - loss: 14.3483 - acc: 0.0960 - val_loss: 15.6144 - val_acc: 0.0312
# Epoch 2/50
# 177/177 [==============================] - 1s 3ms/step - loss: 14.4790 - acc: 0.1017 - val_loss: 15.6144 - val_acc: 0.0312
# Epoch 3/50
# 177/177 [==============================] - 1s 3ms/step - loss: 14.4790 - acc: 0.1017 - val_loss: 15.6144 - val_acc: 0.0312
# Epoch 4/50
# 177/177 [==============================] - 1s 3ms/step - loss: 14.4790 - acc: 0.1017 - val_loss: 15.6144 - val_acc: 0.0312
# Epoch 5/50
# 177/177 [==============================] - 1s 3ms/step - loss: 14.4790 - acc: 0.1017 - val_loss: 15.6144 - val_acc: 0.0312
# Epoch 6/50
# 177/177 [==============================] - 1s 3ms/step - loss: 14.4790 - acc: 0.1017 - val_loss: 15.6144 - val_acc: 0.0312
# Epoch 7/50
# ...
